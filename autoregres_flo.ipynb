# %%
from data_rnn import load_ndfa, load_brackets
# from data_prep import pad_and_convert
import pandas as pd
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# %%
x_train_ndfa, (i2w_ndfa, w2i_ndfa) = load_ndfa(n=150_000)
x_train_brackets, (i2w_brackets, w2i_brackets) = load_brackets(n=150_000)

# %%
print(''.join([i2w_ndfa[i] for i in x_train_ndfa[50]]))
# Out:
# ss

# %%
w2i_ndfa
# Out:
# {'.pad': 0,
#  '.start': 1,
#  '.end': 2,
#  '.unk': 3,
#  'l': 4,
#  '!': 5,
#  'u': 6,
#  'b': 7,
#  'c': 8,
#  's': 9,
#  'm': 10,
#  'k': 11,
#  'a': 12,
#  'v': 13,
#  'w': 14}

# %%
# print(''.join([i2w_brackets[i] for i in x_train_brackets[10_000]]))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class LSTM(nn.Module):
    def __init__(self, vocab_size, emb_size, h, num_char, n_layers=1):
        super(LSTM, self).__init__()

        self.embedding = nn.Embedding(vocab_size, emb_size)
        self.lstm = nn.LSTM(input_size=emb_size, hidden_size=h, num_layers=n_layers, batch_first=True)
        self.fc = nn.Linear(h, num_char)
    
    def forward(self, input_seq, h=None):
        embedded = self.embedding(input_seq)
        lstm_out, hidden = self.lstm(embedded, h)
        # lstm_out = lstm_out[:, -1, :]
        output = self.fc(lstm_out)
        # raise Exception('stop')
        return output, hidden

# %%
def pad_and_convert3(batch, w2i, batch_size):
    start_token = w2i['.start']
    end_token = w2i['.end']
    pad_token = w2i['.pad']

    num_examples = len(batch)
    num_batches = (num_examples + batch_size - 1) // batch_size
    
    # Create batches
    batches = [batch[i * batch_size: (i + 1) * batch_size] for i in range(num_batches)]
    
    padded_batches = []
    
    for b in batches:
        # Pad each sequence in the batch to the maximum length within the batch
        b = [[start_token] + x + [end_token] for x in b]
        max_len = max(len(x) for x in b)
        padded_batch = [x + [pad_token] * (max_len - len(x)) for x in b]
        padded_batches.append(padded_batch)

    # Convert the padded batches to PyTorch tensors
    padded_batches = [torch.tensor(pb, dtype=torch.long) for pb in padded_batches]

    return padded_batches

# %%
x_train_ndfa_padded3 = pad_and_convert3(x_train_ndfa, w2i_ndfa, batch_size=64)
x_train_brackets_padded3 = pad_and_convert3(x_train_brackets, w2i_brackets, batch_size=64)

# %%
vocab_size = len(w2i_ndfa)
emb_size = 32
h = 16
num_char = vocab_size
n_layers = 1

# %%
model = LSTM(vocab_size=vocab_size, emb_size=emb_size, h=h, num_char=num_char, n_layers=1)

# %%
num_epochs = 3
learning_rate = 0.001

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def create_target2(padded_batches):
    target_batches = []

    for batch in padded_batches:
        target_batch = torch.cat((batch[:, 1:], torch.zeros(batch.size(0), 1).int()), dim=1)
        target_batches.append(target_batch)
    return target_batches

# %%
target_ndfa2 = create_target2(x_train_ndfa_padded3)

# %%
import torch.distributions as dist
def sample(lnprobs, temperature=1.0): 
    """
    Sample an element from a categorical distribution
    :param lnprobs: Outcome logits
    :param temperature: Sampling temperature. 1.0 follows the given
        distribution, 0.0 returns the maximum probability element. :return: The index of the sampled element.
    """
    if temperature == 0.0:
        return lnprobs.argmax()
    p = F.softmax(lnprobs / temperature, dim=0)
    cd = dist.Categorical(p)
    return cd.sample()

# %%
trainloader_ndfa = list(zip(x_train_ndfa_padded3, target_ndfa2))

# %%
for epoch in range(num_epochs):
    total_loss = 0.0

    for batch_idx, (inputs, targets) in enumerate(trainloader_ndfa):

        model.train()        
        optimizer.zero_grad()

        h = None
        
        output, _ = model(inputs, h)
        output = output.reshape(-1, vocab_size)
        targets = targets.reshape(-1)

        loss = criterion(output, targets)  

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    average_loss = total_loss / len(trainloader_ndfa)
    print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {average_loss:.4f}')

torch.save(model.state_dict(), 'lstm_model_ndfa.pth')
# Out:
# Epoch [1/3], Average Loss: 0.1706
# Epoch [2/3], Average Loss: 0.1191
# Epoch [3/3], Average Loss: 0.1125

# %%
model = LSTM(vocab_size=len(set(w2i_brackets)), emb_size=300, h=300, num_char=len(set(w2i_brackets)), n_layers=1)
max_length = 50
for epoch in range(num_epochs):
    total_loss = 0.0

    for batch_idx, (inputs, targets) in enumerate(dataloader_brackets2):
        print(f'Batch Index: {batch_idx}, Batch Size: {inputs.size(0)}')

        model.train()        
        optimizer.zero_grad()

        h = None
        
        output, _ = model(inputs, h)

        print('output shape', output.shape)
        output = output.reshape(-1, vocab_size)
        print('output shape', output.shape)
        targets = targets.reshape(-1)


        loss = criterion(output, targets)  

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        print(f'Epoch [{epoch+1}/{num_epochs}], Iteration [{batch_idx+1}/{len(dataloader_brackets2)}], Loss: {total_loss:.4f}')

        model.eval()
        seed_seq = [w2i_brackets['.start'], w2i_brackets['('], w2i_brackets['('], w2i_brackets[')']]
        seed_input = torch.tensor([seed_seq], dtype=torch.long)
        with torch.no_grad():
            for t in range(max_length - 1):
                output, _ = model(seed_input, h)
                print('output', output[0, -1, :])
                next_token = sample(output[0, -1, :])
                print('next token', next_token)
                seed_seq.append(next_token.item())

                if next_token == w2i_brackets['.end']:
                    break

                seed_input = torch.tensor([[next_token]], dtype=torch.long)
                print('seed seq', seed_seq)
            
            generated_sequence = [''.join(i2w_brackets[i] for i in seed_seq)]
            print(f'Generated Sequence after epoch {epoch+1}: {generated_sequence}')

        average_loss = total_loss / len(dataloader_brackets2.dataset)
        print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {average_loss:.4f}')

torch.save(model.state_dict(), 'lstm_model.pth')
# Out:
# Batch Index: 0, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [1/15000], Loss: 1.8493
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 0, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4, 1, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4, 1, 3, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4, 1, 3, 1, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4, 1, 3, 1, 1, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4, 1, 3, 1, 1, 1, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4, 1, 3, 1, 1, 1, 4, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 1, 3, 1, 1, 0, 5, 0, 5, 4, 1, 3, 1, 1, 1, 4, 3, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().pad.start.unk.start.start.pad(.pad().start.unk.start.start.start).unk.pad.start.end']
# Epoch [1/1], Average Loss: 0.0000
# Batch Index: 1, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [2/15000], Loss: 3.6982
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 3, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 3, 4, 3, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 3, 4, 3, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().unk).unk).start.end']
# Epoch [1/1], Average Loss: 0.0000
# Batch Index: 2, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [3/15000], Loss: 5.5471
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 4, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0, 0, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0, 0, 0, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0, 0, 0, 0, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0, 0, 0, 0, 5, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0, 0, 0, 0, 5, 0, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0, 0, 0, 0, 5, 0, 5, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0, 0, 0, 0, 5, 0, 5, 0, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 4, 1, 1, 0, 0, 0, 0, 5, 0, 5, 0, 0, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()).start.start.pad.pad.pad.pad(.pad(.pad.pad.unk.end']
# Epoch [1/1], Average Loss: 0.0000
# Batch Index: 3, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [4/15000], Loss: 7.3956
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 0, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 0, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 0, 3, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 0, 3, 3, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 0, 3, 3, 3, 0, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()(.pad.unk.unk.unk.pad).end']
# Epoch [1/1], Average Loss: 0.0000
# Batch Index: 4, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [5/15000], Loss: 9.2451
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 0, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 0, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().start.pad)(.end']
# Epoch [1/1], Average Loss: 0.0001
# Batch Index: 5, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [6/15000], Loss: 11.0944
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().end']
# Epoch [1/1], Average Loss: 0.0001
# Batch Index: 6, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [7/15000], Loss: 12.9437
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()((.end']
# Epoch [1/1], Average Loss: 0.0001
# Batch Index: 7, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [8/15000], Loss: 14.7931
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 3, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 3, 0, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 3, 0, 1, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3, 0, 1, 5, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3, 0, 1, 5, 1, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().unk.pad.start(.start.unk.unk.end']
# Epoch [1/1], Average Loss: 0.0001
# Batch Index: 8, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [9/15000], Loss: 16.6419
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 4, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(())(.unk.end']
# Epoch [1/1], Average Loss: 0.0001
# Batch Index: 9, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [10/15000], Loss: 18.4915
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 3, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 3, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 3, 5, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 3, 5, 1, 5, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 3, 5, 1, 5, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 3, 5, 1, 5, 4, 0, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().unk(.start().pad(.end']
# Epoch [1/1], Average Loss: 0.0001
# Batch Index: 10, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [11/15000], Loss: 20.3408
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 0, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 0, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 4, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 0, 4, 3, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 0, 4, 3, 1, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0, 4, 3, 1, 3, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 0, 4, 3, 1, 3, 3, 0, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 0, 4, 3, 1, 3, 3, 0, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 0, 4, 3, 1, 3, 3, 0, 4, 3, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().pad).unk.start.unk.unk.pad).unk).end']
# Epoch [1/1], Average Loss: 0.0001
# Batch Index: 11, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [12/15000], Loss: 22.1903
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 4, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5, 3, 0, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5, 3, 0, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5, 3, 0, 3, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5, 3, 0, 3, 0, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5, 3, 0, 3, 0, 1, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5, 3, 0, 3, 0, 1, 1, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 4, 0, 1, 5, 3, 0, 3, 0, 1, 1, 1, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()).pad.start(.unk.pad.unk.pad.start.start.start.start(.end']
# Epoch [1/1], Average Loss: 0.0001
# Batch Index: 12, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [13/15000], Loss: 24.0399
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0, 4, 3, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0, 4, 3, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0, 4, 3, 4, 0, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0, 4, 3, 4, 0, 5, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0, 4, 3, 4, 0, 5, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0, 4, 3, 4, 0, 5, 4, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 4, 4, 1, 4, 4, 5, 5, 3, 1, 0, 4, 3, 4, 0, 5, 4, 4, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().start.unk))).start))((.unk.start.pad).unk).pad()).start).end']
# Epoch [1/1], Average Loss: 0.0002
# Batch Index: 13, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [14/15000], Loss: 25.8894
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 4, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 4, 3, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 4, 3, 3, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 4, 3, 3, 3, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 4, 3, 3, 3, 3, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()).unk.unk.unk.unk.start.start.end']
# Epoch [1/1], Average Loss: 0.0002
# Batch Index: 14, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [15/15000], Loss: 27.7389
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().start.start).end']
# Epoch [1/1], Average Loss: 0.0002
# Batch Index: 15, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [16/15000], Loss: 29.5885
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()).end']
# Epoch [1/1], Average Loss: 0.0002
# Batch Index: 16, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [17/15000], Loss: 31.4373
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().start)(.end']
# Epoch [1/1], Average Loss: 0.0002
# Batch Index: 17, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [18/15000], Loss: 33.2866
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 0, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5, 4, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5, 4, 1, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5, 4, 1, 4, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5, 4, 1, 4, 5, 5, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5, 4, 1, 4, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5, 4, 1, 4, 5, 5, 4, 5, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 0, 3, 0, 1, 4, 0, 4, 5, 3, 1, 1, 3, 3, 3, 5, 5, 4, 1, 4, 5, 5, 4, 5, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()(.pad.unk.pad.start).pad)(.unk.start.start.unk.unk.unk(().start)(()(.pad.start.end']
# Epoch [1/1], Average Loss: 0.0002
# Batch Index: 18, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [19/15000], Loss: 35.1361
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()((.end']
# Epoch [1/1], Average Loss: 0.0002
# Batch Index: 19, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [20/15000], Loss: 36.9856
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 0, 0, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().pad.pad).end']
# Epoch [1/1], Average Loss: 0.0002
# Batch Index: 20, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [21/15000], Loss: 38.8344
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().unk.end']
# Epoch [1/1], Average Loss: 0.0003
# Batch Index: 21, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [22/15000], Loss: 40.6835
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 3, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()(.unk(.end']
# Epoch [1/1], Average Loss: 0.0003
# Batch Index: 22, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [23/15000], Loss: 42.5329
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().end']
# Epoch [1/1], Average Loss: 0.0003
# Batch Index: 23, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [24/15000], Loss: 44.3822
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().end']
# Epoch [1/1], Average Loss: 0.0003
# Batch Index: 24, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [25/15000], Loss: 46.2306
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()(.start.end']
# Epoch [1/1], Average Loss: 0.0003
# Batch Index: 25, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [26/15000], Loss: 48.0790
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()(.end']
# Epoch [1/1], Average Loss: 0.0003
# Batch Index: 26, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [27/15000], Loss: 49.9284
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().end']
# Epoch [1/1], Average Loss: 0.0003
# Batch Index: 27, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [28/15000], Loss: 51.7761
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 1, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 1, 5, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 1, 5, 3, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()(.start(.unk.start(.end']
# Epoch [1/1], Average Loss: 0.0003
# Batch Index: 28, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [29/15000], Loss: 53.6250
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 4, 3, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 4, 3, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 4, 3, 5, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 4, 3, 5, 5, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 4, 3, 5, 5, 3, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()().unk((.unk.start.pad.end']
# Epoch [1/1], Average Loss: 0.0004
# Batch Index: 29, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [30/15000], Loss: 55.4745
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().end']
# Epoch [1/1], Average Loss: 0.0004
# Batch Index: 30, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [31/15000], Loss: 57.3238
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()(.unk.end']
# Epoch [1/1], Average Loss: 0.0004
# Batch Index: 31, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [32/15000], Loss: 59.1733
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3, 3, 0, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3, 3, 0, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3, 3, 0, 3, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3, 3, 0, 3, 3, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3, 3, 0, 3, 3, 3, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3, 3, 0, 3, 3, 3, 3, 0, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3, 4, 1, 0, 4, 5, 5, 1, 4, 3, 1, 3, 3, 0, 3, 3, 3, 3, 0, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().start.unk).start.pad)((.start).unk.start.unk.unk.pad.unk.unk.unk.unk.pad.unk.unk.end']
# Epoch [1/1], Average Loss: 0.0004
# Batch Index: 32, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [33/15000], Loss: 61.0219
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().unk.start.end']
# Epoch [1/1], Average Loss: 0.0004
# Batch Index: 33, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [34/15000], Loss: 62.8713
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 5, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 1, 5, 1, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 5, 1, 5, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 5, 1, 5, 5, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 1, 5, 1, 5, 5, 1, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 5, 1, 5, 5, 1, 1, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().start(.start((.start.start.pad.start.end']
# Epoch [1/1], Average Loss: 0.0004
# Batch Index: 34, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [35/15000], Loss: 64.7207
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 1, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 1, 4, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 1, 4, 3, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 1, 4, 3, 1, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()(.start).unk.start.start.unk.end']
# Epoch [1/1], Average Loss: 0.0004
# Batch Index: 35, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [36/15000], Loss: 66.5702
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 1, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().start.unk.end']
# Epoch [1/1], Average Loss: 0.0004
# Batch Index: 36, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [37/15000], Loss: 68.4198
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 3, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 3, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().unk.unk.start.end']
# Epoch [1/1], Average Loss: 0.0005
# Batch Index: 37, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [38/15000], Loss: 70.2691
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().end']
# Epoch [1/1], Average Loss: 0.0005
# Batch Index: 38, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [39/15000], Loss: 72.1185
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 0, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 0, 3, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 0, 3, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 3, 5, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 3, 5, 5, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 0, 3, 5, 5, 1, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 0, 3, 5, 5, 1, 1, 5, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().pad.unk((.start.start().end']
# Epoch [1/1], Average Loss: 0.0005
# Batch Index: 39, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [40/15000], Loss: 73.9673
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3, 1, 0, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3, 1, 0, 5, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3, 1, 0, 5, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3, 1, 0, 5, 3, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3, 1, 0, 5, 3, 0, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3, 1, 0, 5, 3, 0, 1, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 5, 1, 4, 0, 1, 1, 5, 3, 1, 0, 0, 5, 3, 1, 0, 5, 3, 0, 1, 1, 1, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()((.start).pad.start.start(.unk.start.pad.pad(.unk.start.pad(.unk.pad.start.start.start.start.end']
# Epoch [1/1], Average Loss: 0.0005
# Batch Index: 40, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [41/15000], Loss: 75.8168
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().end']
# Epoch [1/1], Average Loss: 0.0005
# Batch Index: 41, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [42/15000], Loss: 77.6653
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 1, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 1, 0, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().start.pad.start.pad.end']
# Epoch [1/1], Average Loss: 0.0005
# Batch Index: 42, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [43/15000], Loss: 79.5145
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().end']
# Epoch [1/1], Average Loss: 0.0005
# Batch Index: 43, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [44/15000], Loss: 81.3639
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 5, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 5, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 5, 4, 5, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(()()(.start.end']
# Epoch [1/1], Average Loss: 0.0005
# Batch Index: 44, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [45/15000], Loss: 83.2129
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(3)
# seed seq [1, 5, 5, 4, 0, 3]
# output tensor([ 0.1759,  0.1224, -0.0430,  0.0645, -0.0967,  0.0110])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0, 3, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(1)
# seed seq [1, 5, 5, 4, 0, 3, 0, 1]
# output tensor([-0.0243,  0.1024,  0.0615,  0.0875,  0.1341, -0.1349])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 0, 3, 0, 1, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(().pad.unk.pad.start.pad.end']
# Epoch [1/1], Average Loss: 0.0006
# Batch Index: 45, Batch Size: 10
# output shape torch.Size([10, 1024, 6])
# output shape torch.Size([10240, 6])
# Epoch [1/1], Iteration [46/15000], Loss: 85.0623
# output tensor([-0.0378,  0.0149, -0.0281,  0.0786,  0.1398, -0.0557])
# next token tensor(4)
# seed seq [1, 5, 5, 4, 4]
# output tensor([-0.0062,  0.0045, -0.0845,  0.0530,  0.0251, -0.0248])
# next token tensor(5)
# seed seq [1, 5, 5, 4, 4, 5]
# output tensor([-0.0402, -0.0060, -0.0307,  0.0648,  0.0045, -0.0872])
# next token tensor(0)
# seed seq [1, 5, 5, 4, 4, 5, 0]
# output tensor([-0.0309,  0.0400, -0.0891,  0.0500,  0.0425,  0.0024])
# next token tensor(2)
# Generated Sequence after epoch 1: ['.start(())(.pad.end']
# Epoch [1/1], Average Loss: 0.0006
# Batch Index: 46, Batch Size: 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[184], line 14
#      10 optimizer.zero_grad()
#      12 h = None
# ---> 14 output, _ = model(inputs, h)
#      16 print('output shape', output.shape)
#      17 output = output.reshape(-1, vocab_size)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[181], line 11, in LSTM.forward(self, input_seq, h)
#       9 def forward(self, input_seq, h=None):
#      10     embedded = self.embedding(input_seq)
# ---> 11     lstm_out, hidden = self.lstm(embedded, h)
#      12     # lstm_out = lstm_out[:, -1, :]
#      13     output = self.fc(lstm_out)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/rnn.py:812, in LSTM.forward(self, input, hx)
#     810 self.check_forward_args(input, hx, batch_sizes)
#     811 if batch_sizes is None:
# --> 812     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     813                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     814 else:
#     815     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     816                       self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:
